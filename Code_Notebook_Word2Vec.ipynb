# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
from keras.preprocessing.text import Tokenizer
from sklearn import preprocessing
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from tensorflow.keras import callbacks 
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from keras.utils import np_utils
from mlxtend.plotting import plot_confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedKFold
from tqdm import tqdm
from sklearn.model_selection import cross_val_score

# %%
h_train = pd.read_json("../input/nlp-s6-proj-data/Headline_Trainingdata.json")
h_val = pd.read_json("../input/nlp-s6-proj-data/Headline_Trialdata.json")
h_test = pd.read_json("../input/nlp-s6-proj-data/Headlines_Testdata.json")

# %% [markdown]
# ## Headline

# %%
h_train.head()
# Out:
#    id    company                                              title  sentiment
# 0   2  Morrisons  Morrisons book second consecutive quarter of s...      0.430
# 1   3        IMI  IMI posts drop in first-quarter organic revenu...     -0.344
# 2   4   Glencore  Glencore to refinance its short-term debt earl...      0.340
# 3   5    Ryanair  EasyJet attracts more passengers in June but s...      0.259
# 4   6   Barclays             Barclays 'bad bank' chief to step down     -0.231

# %%
h_train.values[0]
# Out:
# array([2, 'Morrisons',
#        'Morrisons book second consecutive quarter of sales growth', 0.43],
#       dtype=object)

# %%
pos_neg_neu_train = {-1:[], 0:[], 1:[]}

for i in h_train.values:
    if(i[3]>-1 and i[3]<=-0.25):
        pos_neg_neu_train[-1].append([i[3], i[2]])
    if(i[3]>-0.25 and i[3]<=0.25):
        pos_neg_neu_train[0].append([i[3], i[2]])
    if(i[3]>0.25 and i[3]<=1):
        pos_neg_neu_train[1].append([i[3], i[2]])

# %%
print('Negative headlines => ', str(len(pos_neg_neu_train[-1])),'\nNeutral headlines => ', str(len(pos_neg_neu_train[0])),'\nPositive headlines => ', str(len(pos_neg_neu_train[1])))
# Out:
# Negative headlines =>  317
# Neutral headlines =>  428
# Positive headlines =>  397

# %%
pos_neg_neu_val = {-1:[], 0:[], 1:[]}

for i in h_val.values:
    if(i[3]>-1 and i[3]<=-0.25):
        pos_neg_neu_val[-1].append([i[1], i[3]])
    if(i[3]>-0.25 and i[3]<=0.25):
        pos_neg_neu_val[0].append([i[1], i[3]])
    if(i[3]>0.25 and i[3]<=1):
        pos_neg_neu_val[1].append([i[1], i[3]])

# %%
pos_neg_neu_val
# Out:
# {-1: [['Tesco says UK store closures put 2000 jobs at risk', -0.9],
#   ['Reed Elsevier share price slides on underwhelming full-year results',
#    -0.9],
#   ['Kingfisher bid for Mr Bricolage runs into trouble', -0.30000000000000004],
#   ['Kingfisher bid for Mr Bricolage runs into trouble', -0.30000000000000004]],
#  0: [['Diageo stays neutral on India boardroom turmoil', -0.2],
#   ['BP ends 27-year sponsorship of Tate as falling oil price takes toll',
#    -0.2]],
#  1: [["CRH's concrete bid for Holcim Lafarge assets", 0.30000000000000004],
#   ["CRH's concrete bid for Holcim Lafarge assets", 0.30000000000000004],
#   ["Glencore's annual results beat forecasts", 0.9],
#   ['Markets Shire up 2.5% and Baxalta up 6% on $32bn deal', 0.8],
#   ['Markets Shire up 2.5% and Baxalta up 6% on $32bn deal', 0.8]]}

# %%
print('Negative headlines => ', str(len(pos_neg_neu_val[-1])),'\nNeutral headlines => ', str(len(pos_neg_neu_val[0])),'\nPositive headlines => ', str(len(pos_neg_neu_val[1])))
# Out:
# Negative headlines =>  4
# Neutral headlines =>  2
# Positive headlines =>  5

# %%
X_vals_tr = []
for i in pos_neg_neu_train:
    for j in pos_neg_neu_train[i]:
        X_vals_tr.append([j[1]])
        if(i == -1):
            X_vals_tr[-1].extend(['Negative'])
        elif(i == 0):
            X_vals_tr[-1].extend(['Neutral'])
        else:
            X_vals_tr[-1].extend(['Positive'])
X_vals_tr = np.array(X_vals_tr)

# %%
X_vals_tr[0]
# Out:
# array(['IMI posts drop in first-quarter organic revenue; warns on full year',
#        'Negative'], dtype='<U116')

# %%
headLine_train = pd.DataFrame({'Title':X_vals_tr[:,0],'Sentiment':X_vals_tr[:,1]})

# %%
X_vals_vl = []
for i in pos_neg_neu_val:
    for j in pos_neg_neu_val[i]:
        X_vals_vl.append([j[0]])
        if(i == -1):
            X_vals_vl[-1].extend(['Negative'])
        elif(i == 0):
            X_vals_vl[-1].extend(['Neutral'])
        else:
            X_vals_vl[-1].extend(['Positive'])
X_vals_vl = np.array(X_vals_vl)

# %%
X_vals_vl[0]
# Out:
# array(['Tesco says UK store closures put 2000 jobs at risk', 'Negative'],
#       dtype='<U67')

# %%
headLine_val = pd.DataFrame({'Title':X_vals_vl[:,0],'Sentiment':X_vals_vl[:,1]})

# %%
headLine_val.head()
# Out:
#                                                Title Sentiment
# 0  Tesco says UK store closures put 2000 jobs at ...  Negative
# 1  Reed Elsevier share price slides on underwhelm...  Negative
# 2  Kingfisher bid for Mr Bricolage runs into trouble  Negative
# 3  Kingfisher bid for Mr Bricolage runs into trouble  Negative
# 4    Diageo stays neutral on India boardroom turmoil   Neutral

# %%
headLine_train.head()
# Out:
#                                                Title Sentiment
# 0  IMI posts drop in first-quarter organic revenu...  Negative
# 1  Barclays share price subdued as bank faces fre...  Negative
# 2  Diageo sales disappoint as currency and compar...  Negative
# 3  Smith & Nephew recalls hip-replacement components  Negative
# 4  Tesco is torn apart as watchdog finds supermar...  Negative

# %%
headLine = pd.concat([headLine_train,headLine_val])

# %%
headLine.head()
# Out:
#                                                Title Sentiment
# 0  IMI posts drop in first-quarter organic revenu...  Negative
# 1  Barclays share price subdued as bank faces fre...  Negative
# 2  Diageo sales disappoint as currency and compar...  Negative
# 3  Smith & Nephew recalls hip-replacement components  Negative
# 4  Tesco is torn apart as watchdog finds supermar...  Negative

# %% [markdown]
# # Word2Vec

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from gensim.models import Word2Vec

# %%
from nltk.tokenize import word_tokenize

# %%
import gensim

# %%
pretext_h=headLine["Title"].apply(gensim.utils.simple_preprocess)

# %%
pretex=[" ".join(i) for i in pretext_h]

# %%
pretext_h = [i for i in pretext_h.values]

# %%
wvmodel = Word2Vec(pretext_h, vector_size=300, window=3, min_count=1, workers=4)

# %%
train_features = []
for i in tqdm(pretext_h):
    s = np.zeros(wvmodel.vector_size,dtype='float32')
    for j in i:
        s+=wvmodel.wv.get_vector(wvmodel.wv.key_to_index[j])
    train_features.append(s)
train_features = np.array(train_features)
# Out:
# 100%|██████████| 1153/1153 [00:00<00:00, 18564.50it/s]

# %%
train_labels = headLine['Sentiment'].values

# %%
train_features, test_features, train_labels, test_labels = train_test_split(train_features, train_labels, test_size=0.2, random_state=42)

# %%
train_features.shape
# Out:
# (922, 300)

# %%
test_features.shape
# Out:
# (231, 300)

# %% [markdown]
# # Model Training

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn import svm

# %%
clf = LogisticRegression(random_state=0, solver='lbfgs', penalty='l2')

# %%
clf.fit(train_features, train_labels)
# Out:
# LogisticRegression(random_state=0)

# %%
# print('Validation Accuracy= '+str(clf.score(val_features, val_labels))+'%')
# for train data:        
print('From train set Accuracy= '+str(clf.score(test_features, test_labels))+'%')
# Out:
# From train set Accuracy= 0.41125541125541126%

# %%
clf = svm.SVC(degree=5)
clf.fit(train_features, train_labels)
# Out:
# SVC(degree=5)

# %%
scores = cross_val_score(clf, test_features, test_labels, cv=10)

# %%
# print('Validation Accuracy= '+str(clf.score(val_features, val_labels))+'%')
# for train data:        
print('From train set Accuracy= '+str(np.mean(scores))+'%')
# Out:
# From train set Accuracy= 0.37228260869565216%

# %%
clf = make_pipeline(StandardScaler(),svm.SVC(random_state=0, degree=10, tol=1e-5, C=2.))
clf.fit(train_features, train_labels)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('svc', SVC(C=2.0, degree=10, random_state=0, tol=1e-05))])

# %%
scores = cross_val_score(clf, test_features, test_labels, cv=10)

# %%
# print('Validation Accuracy= '+str(clf.score(val_features, val_labels))+'%')
# for train data:        
print('From train set Accuracy= '+str(np.mean(scores))+'%')
# Out:
# From train set Accuracy= 0.47228260869565214%

# %%
clf = RandomForestClassifier(max_depth=50, random_state=0, criterion='entropy')
clf.fit(train_features, train_labels)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=50, random_state=0)

# %%
scores = cross_val_score(clf, test_features, test_labels, cv=10)

# %%
# print('Validation Accuracy= '+str(clf.score(val_features, val_labels))+'%')
# for train data:        
print('From train set Accuracy= '+str(np.mean(scores))+'%')
# Out:
# From train set Accuracy= 0.4545289855072464%

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
clf = KNeighborsClassifier(n_neighbors=20)
clf.fit(train_features, train_labels)
# Out:
# KNeighborsClassifier(n_neighbors=20)

# %%
scores = cross_val_score(clf, test_features, test_labels, cv=10)

# %%
# print('Validation Accuracy= '+str(clf.score(val_features, val_labels))+'%')
# for train data:        
print('From train set Accuracy= '+str(np.mean(scores))+'%')
# Out:
# From train set Accuracy= 0.4197463768115942%

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
clf = GradientBoostingClassifier(n_estimators=75, learning_rate=1.0, max_depth=1, random_state=0)
clf.fit(train_features, train_labels)
# Out:
# GradientBoostingClassifier(learning_rate=1.0, max_depth=1, n_estimators=75,
#                            random_state=0)

# %%
scores = cross_val_score(clf, test_features, test_labels, cv=10)

# %%
# print('Validation Accuracy= '+str(clf.score(val_features, val_labels))+'%')
# for train data:        
print('From train set Accuracy= '+str(np.mean(scores))+'%')
# Out:
# From train set Accuracy= 0.4115942028985507%

# %% [markdown]
# ## Microblogs

# %%
mb_train = pd.read_json("../input/nlp-s6-proj-data/Microblog_Trainingdata.json")
mb_val = pd.read_json("../input/nlp-s6-proj-data/Microblog_Trialdata.json")
mb_test = pd.read_json("../input/nlp-s6-proj-data/Microblogs_Testdata.json")

# %% [markdown]
# ## Headline

# %%
mb_train.head()
# Out:
#        source cashtag  sentiment score                  id  \
# 0     twitter     $FB            0.366  719659409228451840
# 1     twitter    $LUV            0.638  719904304207962112
# 2  stocktwits   $NFLX           -0.494             5329774
# 3     twitter    $DIA            0.460  719891468173844480
# 4  stocktwits   $PLUG            0.403            20091246
#
#                                                spans
# 0                     [watching for bounce tomorrow]
# 1       [record number of passengers served in 2015]
# 2                                   [out $NFLX -.35]
# 3  [Looking for a strong bounce, Lunchtime rally ...
# 4  [Very intrigued with the technology and growth...

# %%
mb_train.values[0]
# Out:
# array(['twitter', '$FB', 0.366, 719659409228451840,
#        list(['watching for bounce tomorrow'])], dtype=object)

# %%
mb_train.head()
# Out:
#        source cashtag  sentiment score                  id  \
# 0     twitter     $FB            0.366  719659409228451840
# 1     twitter    $LUV            0.638  719904304207962112
# 2  stocktwits   $NFLX           -0.494             5329774
# 3     twitter    $DIA            0.460  719891468173844480
# 4  stocktwits   $PLUG            0.403            20091246
#
#                                                spans
# 0                     [watching for bounce tomorrow]
# 1       [record number of passengers served in 2015]
# 2                                   [out $NFLX -.35]
# 3  [Looking for a strong bounce, Lunchtime rally ...
# 4  [Very intrigued with the technology and growth...

# %%
pos_neg_neu_train = {-1:[], 0:[], 1:[]}

for i in mb_train.values:
    if(i[2]>-1 and i[2]<=-0.25):
        if(len(i[4])==1):
            pos_neg_neu_train[-1].append([i[4][0], i[2]])
        elif(len(i[4])>1):
            for k in i[4]:
                pos_neg_neu_train[-1].append([i[4][0], i[2]])
    if(i[2]>-0.25 and i[2]<=0.25):
        if(len(i[4])==1):
            pos_neg_neu_train[0].append([i[4][0], i[2]])
        elif(len(i[4])>1):
            for k in i[4]:
                pos_neg_neu_train[0].append([i[4][0], i[2]])
    if(i[2]>0.25 and i[2]<=1):
        if(len(i[4])==1):
            pos_neg_neu_train[1].append([i[4][0], i[2]])
        elif(len(i[4])>1):
            for k in i[4]:
                pos_neg_neu_train[1].append([i[4][0], i[2]])

# %%
pos_neg_neu_train
# Out:
# {-1: [['out $NFLX -.35', -0.494],
#   ['overbought', -0.296],
#   ['absolute garbage still up', -0.546],
#   ['absolute garbage still up', -0.546],
#   ['absolute garbage still up', -0.546],
#   ['Biggest Market Losers', -0.438],
#   ['$GOOG $GOOGL would suck', -0.398],
#   ["who won't pay anymore", -0.349],
#   ["who won't pay anymore", -0.349],
#   ['now seems like its helping the downtrend', -0.372],
#   ['big dumping', -0.699],
#   ['big dumping', -0.699],
#   ['Stochastic Overbought', -0.385],
#   ['Insiders Are Selling', -0.351],
#   ['What goes up...', -0.514],
#   ['if $249.84 breaks we see $245 then $240', -0.519],
#   ['Put the chum out there at key support then next level down', -0.32],
#   ['Put the chum out there at key support then next level down', -0.32],
#   ['Alibaba IPO hoopla canâ€™t hide risk of Chinese stocks', -0.39],
#   ['$MDXG', -0.402],
#   ['$MDXG', -0.402],
#   ['Biggest Market Losers', -0.438],
#   ['hip sinking?', -0.411],
#   ['placed an order to sell 5 shares', -0.379],
#   ['Short Setups Looking Nice....Really Nice', -0.464],
#   ['but man this is one to be careful with', -0.291],
#   ['downgrade', -0.463],
#   ['Short $TSLA calls', -0.618],
#   ['Will re-enter short on bounce..', -0.46],
#   ['all going down', -0.559],
#   ['', -0.373],
#   ['Bottom Losses', -0.473],
#   ['Thanks for the short', -0.264],
#   ['Stochastic Overbought', -0.516],
#   ['new squeeze plays', -0.339],
#   ['$CRM Seems a little to high also', -0.344],
#   ['Currently it is the shorts rejoicing', -0.54],
#   ['$MDXG', -0.361],
#   ['$MDXG', -0.361],
#   ['Your shit is broke', -0.348],
#   ['down $2.84 premarket', -0.512],
#   ['Guess who sold off about $800 million in $MDLZ', -0.428],
#   ['Another Sell Rating, Sell Rating', -0.513],
#   ['highest down volume in last 10 days', -0.31],
#   ['gets 26 patents and goes down', -0.373],
#   ['I think the DNF crew can get this $NFLX short into the next 30 days heading into earnings',
#    -0.308],
#   ['red $AAPL dragging down $QQQ', -0.5],
#   ['weakness continues again.', -0.41],
#   ['Bad governance', -0.331],
#   ['Bad governance', -0.331],
#   ['Bottom Losses', -0.756],
#   ['debt crisis entered a dangerous new phase', -0.331],
#   ['Breakup Will Cost Billions', -0.397],
#   ['overbought', -0.296],
#   ['companies shld be worried about iCloud', -0.329],
#   ['Monday sold', -0.37],
#   ['Multi Top on $MCD', -0.474],
#   ['Multi Top on $MCD', -0.474],
#   ['Multi Top on $MCD', -0.474],
#   ['Why is $FB falling?', -0.304],
#   ['$GOGO short', -0.318],
#   ['EU getting closer to charging Google over Android', -0.319],
#   ['stock splits are lipstick on a pig!', -0.347],
#   ['Markets Are Still Acting Weak', -0.443],
#   ['breaking below support', -0.397],
#   ['sold 20% of our concentrated stake', -0.344],
#   ['cracking lower early', -0.511],
#   ['cracking lower early', -0.511],
#   ['cracking lower early', -0.511],
#   ['$FB & $IBB down', -0.527],
#   ["Is Tiffany's overvalued", -0.25],
#   ['', -0.541],
#   ['Bottom Losses', -0.659],
#   ['stopped out even from yesterdays entry', -0.413],
#   ['Micron Shares Pounded On Fears Of Loss Of Business From Apple', -0.596],
#   ['retreats like clockwork', -0.488],
#   ['its time to sell banks', -0.763],
#   ['The losers buying $TSLA at these levels', -0.545],
#   ["Today's losers", -0.317],
#   ['bond buying is signaling some bad moves for the market', -0.361],
#   ['I see more downside in next two weeks', -0.477],
#   ['I see more downside in next two weeks', -0.477],
#   ['I see more downside in next two weeks', -0.477],
#   ['has just about run its course', -0.449],
#   ['has just about run its course', -0.449],
#   ['Biggest Market Losers', -0.438],
#   ['Biggest Market Losers', -0.438],
#   ['with personal story sharing declining', -0.393],
#   ['with personal story sharing declining', -0.393],
#   ["who won't pay anymore", -0.349],
#   ["who won't pay anymore", -0.349],
#   ['Bad governance', -0.331],
#   ['Bad governance', -0.331],
#   ['Short Setups Looking Nice....Really Nice', -0.464],
#   ['should bring $SPX down into the close.', -0.462],
#   ['money flow & stochastic dropping', -0.577],
#   ['money flow & stochastic dropping', -0.577],
#   ['money flow & stochastic dropping', -0.577],
#   ['$GOOG $GOOGL would suck', -0.404],
#   ['valuation is high', -0.355],
#   ['valuation is high', -0.355],
#   ['valuation is high', -0.355],
#   ['valuation is high', -0.355],
#   ['valuation is high', -0.355],
#   ['$WFM dropping below $30 again', -0.499],
#   ['$WFM dropping below $30 again', -0.499],
#   ['$HTZ', -0.341],
#   ['$HTZ', -0.341],
#   ['Recall Adds To Reliability Issues', -0.267],
#   ['no crying you get out', -0.462],
#   ['banks to implode', -0.298],
#   ['banks to implode', -0.298],
#   ['banks to implode', -0.298],
#   ['PC shipments drop to lowest level since 2007', -0.452],
#   ['Tesla to recall 2,700 Model X SUVs over seat issue', -0.31],
#   ['Worst #sentiment for #SP1500 #stocks at market close', -0.479],
#   ['never widen your stop to stay in a trade', -0.412],
#   ['weakest sector this year', -0.458],
#   ['weakest sector this year', -0.458],
#   ['Tesla is recalling 2,700 Model X cars', -0.291],
#   ['Wish had my puts bac', -0.485],
#   ['Out $AAPL', -0.27],
#   ['makes less profit than the sales of $AAPL Watch', -0.641],
#   ['Comparable Store Sales -4%', -0.441],
#   ['sold at 139.26 and flat', -0.695],
#   ['my hospital reits are slaughtered', -0.399],
#   ['i want to cry', -0.595],
#   ['Bottom Losses', -0.411],
#   ['Three black crows followed by a potential bear flag', -0.569],
#   ['Three black crows followed by a potential bear flag', -0.569],
#   ['USIO ops are profitable', -0.362],
#   ['Reasons for caution about Chinese stocks', -0.317],
#   ['earish Trader bets $550K that Stock Will Sell Off', -0.493],
#   ['congrats shorts', -0.494],
#   ['Worst performers today', -0.351],
#   ['Worst performers today', -0.351],
#   ['nt done good with that name so will pass it', -0.319],
#   ['its been nothing but down', -0.43],
#   ['player onto the 211 puts', -0.652],
#   ['is just humming easing overbought', -0.404],
#   ['Ron Johnson tried, and failed, to inject a bit of Apple culture into JC Penney',
#    -0.335],
#   ['agree risky watching very closely', -0.375],
#   ['flop would just get everyone running to the fences.', -0.546],
#   ['Worst #sentiment for #SP1500 #stocks at market close', -0.479],
#   ['new squeeze plays', -0.339],
#   ['Stochastic Overbought', -0.516],
#   ['Stock dropping hard...', -0.626],
#   ['very weak res', -0.263],
#   ['Short Setups Looking Nice....Really Nice', -0.464],
#   ['gist of downgrades was apple failed to make a phone th', -0.312],
#   ['$GRPN having a much better day than $FB', -0.285],
#   ['SS interest rose on 12/15 on day before we hit our lows. http://stks.co/c1QKr',
#    -0.405],
#   ['$FCX 1.9% now', -0.327],
#   ['$FCX 1.9% now', -0.327],
#   ['$SAP Q1 disappoints as #software licenses down', -0.431],
#   ['$SAP Q1 disappoints as #software licenses down', -0.431],
#   ["Today's losers", -0.317],
#   ["Report: Apple signs up for Google's cloud", -0.38],
#   ["Report: Apple signs up for Google's cloud", -0.38],
#   ['down 12% since I alerted it a short sell on 3-25', -0.391],
#   ['$GS is looking weak while this market is moving higher not a good sign',
#    -0.597],
#   ['Short Setups Looking Nice....Really Nice', -0.464],
#   ['Unloaded $16,673 Worth of The Ensign Group, Inc. (NASDAQ:ENSG) Shares',
#    -0.46],
#   ['MU down 2.3% today and down 8.9%', -0.469],
#   ['Sales weak', -0.515],
#   ['Sales weak', -0.515],
#   ['Sales weak', -0.515],
#   ['Bid for Reargument Denied by Judge', -0.354],
#   ["I don't think is the right fit", -0.296],
#   ['Another Sell Rating', -0.389],
#   ['losers', -0.383],
#   ['losers', -0.383],
#   ['losers', -0.383],
#   ['My broker has no shorts who has them?', -0.533],
#   ['trying to drag $bidu with it.', -0.524],
#   ['downgraded to neutral at Deutsche Bank', -0.446],
#   ['downgraded to neutral at Deutsche Bank', -0.446],
#   ['another story stock with an unhappy ending', -0.426],
#   ['look out belooooooowwww', -0.85],
#   ['Biggest Market Losers', -0.438],
#   ['will end up selling for pennies on the dollar', -0.441],
#   ['Still too early for an entry', -0.387],
#   ["won't have anyone buying products", -0.429],
#   ['Short Setups Looking Nice....Really Nice', -0.464],
#   ['$TSLA Recalls 2,700 Model X Vehicle', -0.336],
#   ['$TSLA Recalls 2,700 Model X Vehicle', -0.336],
#   ['very tight on the avail stock for shorting', -0.406],
#   ['Stochastic Overbought', -0.516],
#   ['Bounced off target buy area', -0.299],
#   ['double top reject', -0.341],
#   ['commodity weakness', -0.376],
#   ['sells flat..I am out..', -0.541],
#   ['Bears Take a Clear Near Term Advantage', -0.501],
#   ['Would short $AMZN on any rally', -0.621],
#   ['after losing about $1 billion on $VRX?', -0.643],
#   ['damn me and low priced stocks', -0.482],
#   ['Spy the bubble is in stock buy backs', -0.268],
#   ['SELL signal by $NDX internals', -0.541],
#   ['SELL signal by $NDX internals', -0.541],
#   ['short', -0.453],
#   ['Oil slid to a four-year low after', -0.369],
#   ['Oil slid to a four-year low after', -0.369],
#   ['refuse', -0.35],
#   ['refuse', -0.35],
#   ['sold my 81 calls', -0.312],
#   ["I'd be short $fast", -0.625],
#   ['out of $KRE', -0.381],
#   ['lets see one more dip', -0.274],
#   ['Stares Into the Abyss', -0.325],
#   ['took my proprietary profit exit', -0.334],
#   ['took my proprietary profit exit', -0.334],
#   ['took my proprietary profit exit', -0.334],
#   ['European Debt once again Keeps Stocks Down', -0.374],
#   ['I dumped $PYPL and $PRLB', -0.506],
#   ['So sad to see such a loved company eating dirt.', -0.453],
#   ['Bullshit! All #AppleStores are EMPTY in #China', -0.329],
#   ['downgrade', -0.463],
#   ['Markets Are Still Acting Weak', -0.443],
#   ['shorts likely to take profits into close', -0.503],
#   ['splat! poor Q1 orders', -0.453],
#   ['With Oil Prices Down further, Oil Stocks Looking Less Cheap', -0.42],
#   ['wants lower', -0.37],
#   ['wants lower', -0.37],
#   ['$ENDP being sued by FT', -0.602],
#   ['$ENDP being sued by FT', -0.602],
#   ['trying to drag $bidu with it.', -0.524],
#   ['60% short interest or not', -0.315],
#   ['The momo leaders are taken down one by one', -0.351],
#   ['Stochastic Overbought', -0.385],
#   ['new squeeze plays', -0.339],
#   ['Active puts', -0.49],
#   ['$YHOO have lost 50% since Nov 14', -0.422],
#   ['Failed breakouts & failed setups', -0.419],
#   ['Failed breakouts & failed setups', -0.419],
#   ['high-flyers have been falling', -0.501],
#   ['decision to sell robot business exposes growing pains', -0.289],
#   ['alot to worry about', -0.319],
#   ['Could the pride of social media be gettin ready to fall?', -0.287],
#   ['Could the pride of social media be gettin ready to fall?', -0.287],
#   ['Biggest Market Losers', -0.438],
#   ['uch a bloated valuation', -0.536],
#   ['I Love blood like a vampire.....Keep bleeding for me', -0.391],
#   ['$FB and $IBB still weak', -0.355],
#   ['best scenario going forward is this stock slowly falling everyday',
#    -0.264],
#   ["Today's losers", -0.317],
#   ['Stochastic Overbought', -0.385],
#   ['down 25% since Tue morning.', -0.527],
#   ["Don't like", -0.483],
#   ["Don't like", -0.483],
#   ["Don't like", -0.483],
#   ['GALE stacks up poorly from an insider ownership', -0.314],
#   ["Today's losers", -0.317],
#   ['investors are nervous about outlook, as they should be.', -0.357],
#   ['Biggest Market Losers', -0.438],
#   ['down 5.43 %', -0.392],
#   ['PLUNGING! Back to', -0.628],
#   ['get ready for the 560 *flush*', -0.264],
#   ['Timberrrr', -0.562],
#   ["Moody's downgrade", -0.299],
#   ['SELL signal by $NDX internals', -0.501],
#   ['SELL signal by $NDX internals', -0.501],
#   ['Receivable going to zero', -0.343],
#   ['Cisco also lower', -0.416],
#   ['sell $RHT', -0.591],
#   ['wants to ta', -0.265],
#   ['wants to ta', -0.265],
#   ['companies shld be worried about iCloud', -0.329],
#   ['negative P&L on hardware', -0.387],
#   ['afternoon selloff as usual will be brutal', -0.569],
#   ['afternoon selloff as usual will be brutal', -0.569],
#   ['Short more ', -0.605],
#   ['Short more ', -0.605],
#   ['getting out of his', -0.374],
#   ['With Oil Prices Down further, Oil Stocks Looking Less Cheap', -0.42],
#   ['consumers keep cautious stance', -0.258],
#   ['Locked in some $FB puts for nice gain', -0.524],
#   ['Stochastic Overbought', -0.516],
#   ['not all time low , been lower', -0.268],
#   ['Time to stomp on some dreams.', -0.258],
#   ['my 18 year old and 14 year old are never on $FB ', -0.258],
#   ['my 18 year old and 14 year old are never on $FB ', -0.258],
#   ['may not be as secure', -0.308],
#   ['', -0.272],
#   ['Issues Statement On Debt Ceiling', -0.341],
#   ["there's a good short spot", -0.434],
#   ['Worst performers today', -0.365],
#   ['Worst performers today', -0.365],
#   ['Insiders Are Selling', -0.351],
#   ['Short Setups Looking Nice....Really Nice', -0.464],
#   ['short $MBLY', -0.606],
#   ['will push $NLY investment to another time', -0.255],
#   ['they let the stock fall big time after earnings', -0.455],
#   ['debt crisis entered a dangerous new phase', -0.331],
#   ['$MU may go down 6% if the bear pattern is confirmed', -0.404],
#   ['PAIN', -0.4],
#   ['in trouble ? is that earnings gap still unfilled ?', -0.368],
#   ['sold xoma', -0.281],
#   ['looking weak', -0.352],
#   ['Markets Are Still Acting Weak', -0.443],
#   ['short/put positions looking good here', -0.485],
#   ['short/put positions looking good here', -0.485],
#   ['loading $SPY and $AAPL puts', -0.537],
#   ['loading $SPY and $AAPL puts', -0.537],
#   ['still in bear market', -0.421],
#   ['got hit hard lower this AM', -0.551],
#   ['Embarrassing China numbers', -0.312],
#   ['bumping its head on declining daily 8ma as overhead resistance', -0.35],
#   ['hopefully peeps shorting $CAMT for scalps', -0.36],
#   ['Now it is time to short $TSLA', -0.385],
#   ['Infection worries prompt regulatory reviews', -0.401],
#   ['Back to Back intraday reversals', -0.53],
#   ['Back to Back intraday reversals', -0.53],
#   ['Back to Back intraday reversals', -0.53],
#   ['Markets Are Still Acting Weak', -0.443],
#   ['bear flag', -0.535],
#   ['Brent back below 49', -0.353],
#   ['shipments slid -9.6% to lowest quarterly total since 2007', -0.336],
#   ['shipments slid -9.6% to lowest quarterly total since 2007', -0.336],
#   ['Looks like might break down', -0.516],
#   ['Looks like might break down', -0.516],
#   ['short', -0.633],
#   ['CHUNK OF DEC $35 PUTS BOUGHT AT', -0.601],
#   ['Not Time To Buy', -0.382],
#   ['round 2 short', -0.438],
#   ['debt crisis entered a dangerous new phase', -0.331],
#   ['short the market', -0.541],
#   ['4 shorts only', -0.53],
#   ['have enjoyed shorting Anglo these last few weeks', -0.269],
#   ['$AAPL cleary surpassed their BB', -0.274],
#   ['all going down', -0.559],
#   ['Stochastic Overbought', -0.385],
#   ['downgrade', -0.463],
#   ['NetApp downgraded by Macquarie to underperform', -0.574],
#   ['short the $TSLA', -0.603],
#   ['shipments slid -9.6% to lowest quarterly total since 2007', -0.295],
#   ['shipments slid -9.6% to lowest quarterly total since 2007', -0.295],
#   ['lost revenue', -0.43],
#   ['lost revenue', -0.43],
#   ['$AAPL signs up with Google cloud', -0.403],
#   ['heading back down to', -0.25],
#   ['heading back down to', -0.25],
#   ['obby against Judge Garland or they risk losing the case', -0.261],
#   ['buying my last round of shorts next week', -0.339],
#   ['Monday sold', -0.37],
#   ['shorts made a killing last couple days', -0.529],
#   ['Stock Receives Ratings Downgrade Today at Jefferies', -0.501],
#   ['Looks weak now', -0.504],
#   ['Looks weak now', -0.504],
#   ['small pos, short 180 wkly puts', -0.597],
#   ["isn't cheap", -0.353],
#   ["isn't cheap", -0.353],
#   ['Great short entry right now', -0.461],
#   ['with personal story sharing declining', -0.572],
#   ['with personal story sharing declining', -0.572],
#   ['Bad Apple', -0.392],
#   ['is now beaten down, hated', -0.303],
#   ['they are hitting everything in sight.', -0.504],
#   ['they are hitting everything in sight.', -0.504],
#   ['short somewhere in the high', -0.526],
#   ['short somewhere in the high', -0.526],
#   ['#iPhone is really annoying.', -0.398],
#   ['companies shld be worried about iCloud', -0.329],
#   ['massive logistics capex result in missed earnings', -0.324],
#   ['Elon Muskâ€™s Comparision Of $TSLA With $AAPL Doesnâ€™t Go Well', -0.277],
#   ['downgrade', -0.463],
#   ['$FB and $IBB still weak', -0.373],
#   ['short', -0.339],
#   ['Short 61.8% Retracement', -0.371],
#   ['Short 61.8% Retracement', -0.371],
#   ['$TSLA recall', -0.381],
#   ['$TSLA recall', -0.381],
#   ['$TSLA recall', -0.381],
#   ['topping tail', -0.64],
#   ['topping tail', -0.64],
#   ['NaturalGas Settles At 3-year Low', -0.563],
#   ['Time to stomp on some dreams.', -0.258],
#   ['great short setting up', -0.406],
#   ['$TSLA dump!', -0.866],
#   ['with ex-dividend coming it will fall more', -0.411],
#   ["Today's losers", -0.317],
#   ['$GRPN might be selling off ahead of $P earnings', -0.411],
#   ['I sold $TSLA', -0.348],
#   ['downgrade', -0.463],
#   ['Bottom Losses', -0.575],
#   ["$TSLA is the only 'auto' stock showing a gain year-to-date", -0.347],
#   ['all going down', -0.559],
#   ['Almost an outside day down', -0.274],
#   ['5 Toxic Stocks Raising Red Flags to Sell', -0.826],
#   ['Not Time To Buy', -0.382],
#   ['So many traders short', -0.331],
#   ['fast 56pc dive', -0.26],
#   ['Fast Money says short ahead of Black Friday', -0.448],
#   ['got to short that even at work you jump in money trade', -0.378],
#   ['very tight on the avail stock for shorting', -0.554],
#   ['down 20% in after-hour market', -0.551],
#   ['Big Drop in Hedge Fund Exposure to Market', -0.402],
#   ['Big Drop in Hedge Fund Exposure to Market', -0.402],
#   ['short some', -0.464],
#   ['Getting ready to sell some premiumm', -0.441],
#   ['Stochastic Overbought', -0.516],
#   ['running into cloud bottom', -0.528],
#   ['next Q will be a good short', -0.441],
#   ['Reasons for caution about Chinese stocks', -0.317],
#   ['The Baltic Dry Index has only been lower than this 8 days in 30 years',
#    -0.482],
#   ['Sold: $CELG $AGIO', -0.552],
#   ['Seems like a good short setup', -0.338],
#   ['breaks major support', -0.66],
#   ['Sold all:', -0.57],
#   ['Bricks and Mortar retailers selling cheaper', -0.352],
#   ['Bricks and Mortar retailers selling cheaper', -0.352],
#   ['still in bear market', -0.421],
#   ['bearish engulfing candle', -0.532],
#   ['Tomorrow party time for the Bears!!', -0.528],
#   ['slipping', -0.289],
#   ['downgrade', -0.463],
#   ['earning play $fast 47 puts, $vrx 34 puts , $bidu 182.5 puts', -0.387],
#   ['Sinks to 35', -0.549],
#   ['Stares Into the Abyss', -0.325],
#   ['this is going to end in the red', -0.477],
#   ['near a 3% drop thats a lot', -0.304],
#   ['Sold all:', -0.546],
#   ['With Oil Prices Down further, Oil Stocks Looking Less Cheap', -0.42],
#   ['Stochastic Overbought', -0.516],
#   ['all going down', -0.559],
#   ['SHORT', -0.363],
#   ["who won't pay anymore", -0.349],
#   ["who won't pay anymore", -0.349],
#   ['-0.75% #trading weak', -0.281],
#   ['$LTM Selling far from over', -0.629],
#   ['$LTM Selling far from over', -0.629],
#   ['Another Sell Rating', -0.389],
#   ['valuation downgraded today', -0.375],
#   ['valuation downgraded today', -0.375],
#   ['$TSLA short', -0.505],
#   ['downgrade', -0.463],
#   ['I blew out $ZMH', -0.462],
#   ['wayyy overvalued right now', -0.451],
#   ['wayyy overvalued right now', -0.451],
#   ['BTO three 110 puts @ 1.34', -0.267],
#   ["Apple's iPhone SE: The Sold Out Flop", -0.336],
#   ['short-term forecast is now bearish', -0.343],
#   ['Could the pride of social media be gettin ready to fall?', -0.403],
#   ['Could the pride of social media be gettin ready to fall?', -0.403],
#   ['Market getting crushed today', -0.302],
#   ['down 1.1%', -0.352],
#   ['down 1.1%', -0.352],
#   ['Short Setups Looking Nice....Really Nice', -0.464],
#   ['recessions', -0.307],
#   ['recessions', -0.307],
#   ["new 'large player sells'", -0.498],
#   ['Biggest Market Losers', -0.438],
#   ['and is overbought', -0.48],
#   ['red before the bell', -0.442],
#   ['weak close', -0.297],
#   ['looks like it could be about to fall apart', -0.515],
#   ['looks like it could be about to fall apart', -0.515],
#   ['looks like it could be about to fall apart', -0.515],
#   ['Facebook has now been down 10 minutes', -0.258],
#   ['Tesla Motors recalls', -0.424],
#   ['Do you really think in 4 weeks they capture 10%? Impossible.', -0.317],
#   ['excellent / factual bear argument', -0.507],
#   ['Bears Take a Clear Near Term Advantage', -0.501],
#   ['relative weakness is pretty apparent', -0.262],
#   ['downgrade', -0.463],
#   ['ISRG Short', -0.678],
#   ['-2.10% vs -0.90% Est', -0.489],
#   ['-2.10% vs -0.90% Est', -0.489],
#   ['$VIAB down 40%', -0.516],
#   ['Monday sold', -0.44],
#   ['earning play $fast 47 puts, $vrx 34 puts , $bidu 182.5 puts', -0.387],
#   ['Failed breakouts & failed setups', -0.419],
#   ['Failed breakouts & failed setups', -0.419],
#   ['shorting here into close might be play', -0.469],
#   ['shorting here into close might be play', -0.469],
#   ['Insiders Are Selling', -0.351],
#   ['Insiders Are Selling', -0.351],
#   ['hangin on my a thread', -0.337],
#   ['hangin on my a thread', -0.337],
#   ['recalls 2,700 Model X cars', -0.315],
#   ['defect', -0.366],
#   ['defect', -0.366],
#   ['Tomorrow party time for the Bears!!', -0.524],
#   ['Insiders Are Selling', -0.527],
#   ['small businesses have called $YELP a scam for years', -0.45],
#   ['weekly 120 puts +283%', -0.35],
#   ['I may try a short', -0.352],
#   ['Deutsche Bank downgrades', -0.436],
#   ['accuses $ZNGA of copyright infringement', -0.284],
#   ['shipments slid -9.6% to lowest quarterly total since 2007', -0.283],
#   ['shipments slid -9.6% to lowest quarterly total since 2007', -0.283],
#   ['#joke #bubble #buyerbeware', -0.506],
#   ['$AZPN is worth $20 a share not $40', -0.563],
#   ['$WFC -8.30%', -0.584],
#   ['recessions', -0.307],
#   ['recessions', -0.307],
#   ['buying my last round of shorts next week', -0.339],
#   ['Express Scripts loses', -0.336],
#   ['debt crisis entered a dangerous new phase', -0.331],
#   ['then shorted it down.', -0.405],
#   ['Failed breakouts & failed setups', -0.419],
#   ['Failed breakouts & failed setups', -0.419],
#   ["Moody's downgrade", -0.299],
#   ['Tesla dropped a hard J this morning', -0.376],
#   ['Bears Take a Clear Near Term Advantage', -0.501],
#   ['< Money-Losing$ OverValued China IPO Junk', -0.638],
#   ["honestly, it's been disappointing", -0.443],
#   ['Short Setups Looking Nice....Really Nice', -0.464],
#   ["t's time to short at this point", -0.489],
#   ['today aside setting up for another drop', -0.504],
#   ['today aside setting up for another drop', -0.504],
#   ["$TSLA is the only 'auto' stock showing a gain year-to-date", -0.334],
#   ['bearish charts keep getting worse.', -0.619],
#   ["looking weak and possibly ready to 'let go'", -0.482],
#   ['Bricks and Mortar retailers selling cheaper', -0.352],
#   ['Bricks and Mortar retailers selling cheaper', -0.352],
#   ['Falls 18% Pre-Market on Q3 Sales Results', -0.394],
#   ['Little-Discussed Problem This Pro Is Watching At', -0.476],
#   ['Market seems stuck in the mud', -0.259],
#   ['Stock Trading Lower Today ', -0.375],
#   ['Stock Trading Lower Today ', -0.375],
#   ['bear raid', -0.48],
#   ['curing #overbought conditions', -0.262],
#   ['getting kneecapped by $BEXP selling itself dirt cheap', -0.384],
#   ['getting sold here.', -0.551],
#   ['puts came in', -0.517],
#   ['on lows', -0.465],
#   ['on lows', -0.465],
#   ['5 Reasons Not to Buy Gold', -0.447],
#   ['Slow bleeding death', -0.641],
#   ['Slow bleeding death', -0.641],
#   ['downgrade', -0.463],
#   ['has a 42.71% Float Short. Lo', -0.392],
#   ['has a 42.71% Float Short. Lo', -0.392],
#   ['Stochastic Overbought', -0.385],
#   ['companies shld be worried about iCloud', -0.329],
#   ['short', -0.377],
#   ['will close below ', -0.453],
#   ['will close below ', -0.453],
#   ['they want the stock too keep going up', -0.294],
#   ['Same sellers we saw yesterday', -0.45],
#   ['No need for $FB at all unless you want your content censored', -0.367],
#   ['downgraded to Neutral at Wedbush', -0.434],
#   ['downgraded to Neutral at Wedbush', -0.434],
#   ['Torture.......', -0.303],
#   ['high-flyers have been falling', -0.501],
#   ['breaks major support', -0.455],
#   ['Receives a Sell from Compass Point', -0.45],
#   ['Stochastic Overbought', -0.385],
#   ['anyone long before the flush please accept my condolences', -0.606],
#   ['anyone long before the flush please accept my condolences', -0.606],
#   ['downgrade', -0.463],
#   ['Stochastic Overbought', -0.385],
#   ['Worst performers today', -0.72],
#   ['Worst performers today', -0.72],
#   ['Insiders Are Selling', -0.351],
#   ['Small caps threatening descending triangle breakdown', -0.382],
#   ['$HTZ', -0.409],
#   ['$HTZ', -0.409],
#   ['100.0% increased bearish conversations', -0.589],
#   ['Another Sell Rating, Sell Rating', -0.513],
#   ['sold today', -0.581],
#   ['overbought', -0.296]],
#  0: [['short worked', 0.0],
#   ['short worked', 0.0],
#   ['No edge offered', 0.025],
#   ["I don't think it will move $FB in the short term", -0.042],
#   ['Hold', 0.099],
#   ['#Tesla: Great Company, Bad #Stock $TSLA', -0.065],
#   ['on the fence with this one', 0.0],
#   ['looks like drought conditions in soil already', -0.122],
#   ['nice volume', 0.113],
#   ['nice volume', 0.113],
#   ['Out $BIDU for now', -0.221],
#   ["Was looking for a long entry but today's price action wasn't appealing",
#    0.215],
#   ['just follow the trend, follow the money flow', 0.165],
#   ['tapping on 10.00', 0.224],
#   ['so volatile!', -0.131],
#   ['Short Percent of Float 16.80%', -0.16],
#   ['ure wish bad news came out just a few days earlier', -0.221],
#   ['', 0.0],
#   ['mkt fell on debt downgrade', -0.159],
#   ['mkt fell on debt downgrade', -0.159],
#   ['been very frustrating', -0.136],
#   ['been very frustrating', -0.136],
#   ['need to break $4 again', 0.132],
#   ['Very tight price', 0.0],
#   ['airlines battle for Cuba routes $AAL $LUV $SAVE $JBLU', 0.092],
#   ['BlackBerry Messenger is second only to Facebook in user loyalty', 0.158],
#   ['Weak open and it goes r/g within first 30 mins', -0.229],
#   ['LED light bulb prices rise in Japan', 0.054],
#   ['After weeks of steady gains,advances in mkt breadth slowe', -0.146],
#   ['LED light bulb prices rise in Japan', 0.054],
#   ['is a later riser,', 0.203],
#   ['is a later riser,', 0.203],
#   ['cuts outlook down', -0.236],
#   ["joint bid for Yahoo's internet assets", 0.228],
#   ['I just feel the people who are buying are the same ones with their finger on the sell button',
#    -0.054],
#   ['gap filled', 0.226],
#   ["next resist is 64.40's", 0.201],
#   ['', 0.0],
#   ['looks really toppy right here.', -0.191],
#   ['Buy Call!', 0.095],
#   ['$SPY -0.05%', 0.028],
#   ['US Adds 321K Jobs In November', 0.243],
#   ['US Adds 321K Jobs In November', 0.243],
#   ['US Adds 321K Jobs In November', 0.243],
#   ['moving up again', 0.12],
#   ['$EA points to the two Facebook games', 0.048],
#   ['2m this year would be amazing', 0.151],
#   ['patience on the buy precedes patience on the sell', 0.0],
#   ['brand name is to big for it to fail', 0.226],
#   ['brand name is to big for it to fail', 0.226],
#   ['under pressure along with the market', 0.014],
#   ['wait and see before taking any action', 0.0],
#   ['Higher In Afternoon Trade', 0.243],
#   ['Higher In Afternoon Trade', 0.243],
#   ['Largest Online Gaming Market', 0.226],
#   ['', 0.0],
#   ['holding strong', 0.192],
#   ['not feel terribly good', -0.126],
#   ['$SPY up only 0.6%', 0.228],
#   ['$SPY up only 0.6%', 0.228],
#   ['Gevoâ€™s Alcohol to Jet Fuel Now Eligible to be Used for Commercial Flight',
#    0.026],
#   ['Santa Rally', 0.22],
#   ['Santa Rally', 0.22],
#   ["didn't factor in anything other than google and repeated good earnings",
#    0.102],
#   ['ripe for a squeeze again', -0.216],
#   ['the most trending', 0.216],
#   ['still they are saying bullish LoL', -0.038],
#   ["today's bull flag", 0.2],
#   ['here is no case here', 0.18],
#   ['9% run for this watch list winner', 0.066],
#   ['Not every idea $AMZN has is bad.', 0.235],
#   ['mrkt needs to washout', -0.055],
#   ["I'm out", -0.14],
#   ['Think I may just start to avoid bios', -0.23],
#   ['If bulls lucky enuff to get an upside gap fill, better take it', 0.054],
#   ['near a buy point last week', 0.102],
#   ['consistent gains but small', 0.219],
#   ['consistent gains but small', 0.219],
#   ['$AAPL cult on stocktwits is actually disgusting', -0.151],
#   ['Higher In Afternoon Trade', 0.243],
#   ['Higher In Afternoon Trade', 0.243],
#   ['US Adds 321K Jobs In November', 0.243],
#   ['US Adds 321K Jobs In November', 0.243],
#   ['US Adds 321K Jobs In November', 0.243],
#   ['under pressure along with the market', 0.014],
#   ['I would take profits if you have them', -0.244],
#   ['slips alongside shares on NSA leak news', -0.198],
#   ['see if they maintain 15% yield', 0.078],
#   ['see if they maintain 15% yield', 0.078],
#   ['As with all 3x ETFs, it is subject to decay due to daily rebalancin',
#    -0.234],
#   ['As with all 3x ETFs, it is subject to decay due to daily rebalancin',
#    -0.234],
#   ['I rather be neutral to bullish rather than bearish', 0.185],
#   ['Diversifies. Adds International exposure', 0.219],
#   ['capped', -0.172],
#   ['capped', -0.172],
#   ['long on', 0.185],
#   ['$GOOGL patents turn signal detector for autonomous cars.', 0.241],
#   ['suddenly realizing', -0.147],
#   ['$FIT and $SUNE have not changed.', -0.179],
#   ['just follow the trend, follow the money flow', 0.165],
#   ['Short Squeeze Ready To Upside w Crossing Important Technical Level',
#    0.219],
#   ['I love this stock/Co', -0.125],
#   ['$TSLA hype the news', -0.073],
#   ['$TSLA hype the news', -0.073],
#   ['trails $MSFT $ORCL $GOOG $CRM $ADBE', 0.177],
#   ['just follow the trend, follow the money flow', 0.165],
#   ['is up 19%', 0.128],
#   ['not the prettiest candlesticks', 0.0],
#   ['not the prettiest candlesticks', 0.0],
#   ['Took Small posistion on $TSLA', -0.114],
#   ['people are calling it bearish', -0.148],
#   ['people are calling it bearish', -0.148],
#   ['Fader play here', -0.219],
#   ['Recall will not impact financial results', 0.198],
#   ['cover all', 0.114],
#   ['Going back in, but slowly', 0.119],
#   ['the parties over', -0.223],
#   ['the parties over', -0.223],
#   ['640m globally this week on avengers really sick ,Stan lee is a beast',
#    0.24],
#   ['plus its Irish based', 0.226],
#   ['plus its Irish based', 0.226],
#   ['getting a lot of hype', 0.095],
#   ['it With Lawsuit from Russian Search Engine', -0.17],
#   ['the most trending', 0.216],
#   ['', 0.0],
#   ['Will be adding on dips', 0.154],
#   ["losing $400M of $AAPL's business", -0.015],
#   ['bounce right now has no vol, more vol when it slid', 0.19],
#   ['has had a history of a lack of PR', -0.21],
#   ['has had a history of a lack of PR', -0.21],
#   ['To Combine In $37 Billion Deal', 0.241],
#   ['There is a good base building', 0.228],
#   ['SOLD to close $QQQ puts for +34%', -0.059],
#   ['triple top forming.', 0.028],
#   ['Whole Foods shareholders vote down activist initiatives', -0.076],
#   ['Imagine $AAPL TV impact!! $$$', 0.24],
#   ['Southwest Is at Its Lowest Multiple Ever', 0.106],
#   ['Today I bought more', 0.087],
#   ['this pull back of', -0.03],
#   ['$TFM will have a way to go price wise to compete with Kroger. $KR', 0.129],
#   ['Will A Onetime Zombie Stock Rise Again?', 0.241],
#   ["today's bull flag", 0.2],
#   ['Bullshit', -0.209],
#   ['$X +2.27%', 0.144],
#   ['this is what you get', -0.007],
#   ['$BABA is going to be an interesting one', 0.233],
#   ['sideways', 0.0],
#   ['green, lol... make-up to cover ugliness', 0.242],
#   ['$MSFT is opening up its #XboxLive online service', 0.225],
#   ['at resistance right here', -0.105],
#   ['at resistance right here', -0.105],
#   ['Holding', 0.171],
#   ["finally broke free from big brother's shadow?", 0.206],
#   ['the most trending', 0.216],
#   ['No edge offered', 0.025],
#   ['Something big is gonna happen here', 0.0],
#   ['Double bottom 5.2', 0.23],
#   ['consistent gains but small', 0.219],
#   ['consistent gains but small', 0.219],
#   ['watching paint dry', 0.0],
#   ['watching paint dry', 0.0],
#   ['Fundamentally nothing has changed', 0.198],
#   ['$YHOO refuse of $MSFT offer of 45 B is going to go down as one of the worst decisions ever.',
#    0.012],
#   ['eyeing $RA w take-over interest', 0.041],
#   ['bail out', 0.058],
#   ['CFO Sees Profitability From', 0.211],
#   ['CFO Sees Profitability From', 0.211],
#   ['Strictly day trading this one long and short off 5 minute', 0.035],
#   ['Will this cold put a dent in the massive horizontal rig production',
#    -0.237],
#   ['Over the TL it can go to 114, below it can go to 90.', 0.0],
#   ['then trail up.', 0.236],
#   ['yet not that much (price) has changed', 0.036],
#   ['I see no reason to sell yet', -0.093],
#   ['Keeping my stops a bit on the tight side', 0.135],
#   ['', 0.0],
#   ['strong buy within a month', 0.119],
#   ['Drop expected', -0.002],
#   ['Worth a chance here', 0.145],
#   ['expects to break even', 0.219],
#   ['Adobe Receives New Rating from Top Analyst', 0.141],
#   ['We See More Reasons To Be Cautious', -0.093],
#   ['plus its Irish based', 0.146],
#   ['plus its Irish based', 0.146],
#   ["If that's what you want then buy some", 0.245],
#   ['Just sold 2 Apr-22 115 calls', -0.024],
#   ['remember when Zuck in 2010 told us he was going to fix email with it?',
#    0.091],
#   ['Continues to base on the weekly chart', -0.047],
#   ['may not be bad', 0.081],
#   ['may not be bad', 0.081],
#   ['may not be bad', 0.081],
#   ['Dailymail content is perfect for YHOO demographics', 0.153],
#   ['It Needs A New Tablet Strategy', -0.195],
#   ['Taking some profits', -0.142],
#   ['3-star analyst Joe Wittine from Longbow Research reiterated a HOLD rating',
#    0.214],
#   ['still having some trouble at the resistance line', 0.071],
#   ['Apple hires former Amazon executive George Stathakopoulos as head of corporate data security',
#    0.146],
#   ['has been slipping', -0.245],
#   ['this one is looking beat up and interesting', -0.084],
#   ['$amd is a two dollar spec play', -0.163],
#   ['$amd is a two dollar spec play', -0.163],
#   ['starting to creep up', -0.014],
#   ['minuscule 0.09% gain in $ZIV', -0.059],
#   ['minuscule 0.09% gain in $ZIV', -0.059],
#   ['airlines battle for Cuba routes $AAL $LUV $SAVE $JBLU', 0.092],
#   ['next 5-6 charts illustrate a bullish weekly outcome', 0.119],
#   ['I would buy some wtsl at these prices', 0.193],
#   ['volume footprint looks great', -0.097],
#   ['gap fill 53.53 still waiting.', 0.085],
#   ['strong 5min @above bollies', 0.235],
#   ['near a buy point last week', 0.093],
#   ['start strong finish weak', -0.086],
#   ['$AAPL max pain', -0.063],
#   ['$FB is taking the shine off $AAPL and $GOOG', -0.13],
#   ['$NFLX more positive comments from $MS', 0.085],
#   ['more test of 12.85 coming up', 0.152],
#   ['RSI lowest level since October 2012', 0.165],
#   ['$YOKU 0', 0.0],
#   ['Google Will Soon Start Selling Chromebooks At Walmart And Staples', 0.196],
#   ['less than stellar day but it held the 50 day moving average', -0.14],
#   ['A beautifully orchestrated marke', 0.152],
#   ['up 7$', 0.177],
#   ['Long', 0.23],
#   ['Long', 0.23],
#   ['', 0.0],
#   ['Today I bought more', 0.087],
#   ['can ONE of the cheerleaders show me actual valuation work', -0.205],
#   ["Report: Apple signs up for Google's cloud", 0.15],
#   ['point at a possible move up', 0.176],
#   ['not selling before', 0.221],
#   ['longer term top building', 0.099],
#   ['longer term top building', 0.099],
#   ['cracking', -0.118],
#   ['bull move ended', -0.204],
#   ['bull move ended', -0.204],
#   ['bought back more shares here today', 0.243],
#   ['getting very close to 200 MA of 110.87, hasnâ€™t closed above 200 MA since July 31, 2015. If / when it does, will be significant.',
#    0.218],
#   ['nice blurb for $BBRY', 0.183],
#   ['weak outlook', -0.034],
#   ['Indices are rallying today', -0.193],
#   ['Indices are rallying today', -0.193],
#   ['Possible target', 0.162],
#   ['', 0.0],
#   ["At least you didn't stop out", -0.222],
#   ['Long-Term Potential Robust', 0.249],
#   ['acting tough on big volume against the tape', 0.243],
#   ['Weekly 625 calls now +42.31%', 0.144],
#   ['has been a bull and $gld a bear', 0.0],
#   ['the most trending', 0.216],
#   ['$NFLX at $44B', 0.215],
#   ['Seeing Competition', -0.216],
#   ['tired of seeing this go down', -0.085],
#   ['Covered', 0.128],
#   ['Closed short position', 0.143],
#   ['Why $TWTR is doomed in 1 chart', -0.027],
#   ['Global PC shipments fell 9.6% in Q1', -0.152],
#   ['Global PC shipments fell 9.6% in Q1', -0.152],
#   ['Deutsche Bank: cuts #Starbucks to Hold', -0.17],
#   ['Deutsche Bank: cuts #Starbucks to Hold', -0.17],
#   ['breaking out', 0.068],
#   ['only those with the stomach for high risk are left', -0.151],
#   ['Men sell $SVXY puts', 0.092],
#   ['atching SPY 60 min STO for a push', -0.035],
#   ['Can $TSLA roll over yet?', -0.212],
#   ['downward trendline', -0.143],
#   ['Risky move', -0.078],
#   ['actively Head & Shoulder in progress', -0.222],
#   ['worst performers', -0.244],
#   ['', 0.0],
#   ['daily sales slowing again', -0.105],
#   ['Announces Record #Esports Viewership', 0.208],
#   ['only a 50% gain from these levels', -0.22],
#   ['US Adds 321K Jobs In November', 0.183],
#   ['US Adds 321K Jobs In November', 0.183],
#   ['US Adds 321K Jobs In November', 0.183],
#   ['start strong finish weak', -0.086],
#   ['guess everyone wants 620', 0.239],
#   ['As for $TWTR, no words.', -0.188],
#   ['nice in an out couple mini trades', 0.121],
#   ['its a decent Co should get bought', 0.214],
#   ['its a decent Co should get bought', 0.214],
#   ["doesn't make any real money", -0.163],
#   ["doesn't make any real money", -0.163],
#   ["doesn't make any real money", -0.163],
#   ['Long', 0.23],
#   ['Long', 0.23],
#   ['no trade for now', 0.123],
#   ['support 212.93 no support to 209.45', 0.166],
#   ['$AAPL a new long IF 110.61 is broke', 0.172],
#   ['#offshoring #jobs & #production', 0.228],
#   ['There is massive short squeeze opportunity here', -0.104],
#   ['Micron Shares Pounded On Fears Of Loss Of Business From Apple', 0.071],
#   ['Covered all my $sina shorts', 0.047],
#   ['2 retailers whose stocks I own', 0.227],
#   ['75k just went through on the ask', -0.167],
#   ['Considering Bid', 0.21],
#   ['is waking up', 0.192],
#   ['Indices are rallying today', -0.182],
#   ['Indices are rallying today', -0.182],
#   ['resistance breached last week', 0.112],
#   ['#Tesla: Great Company, Bad #Stock $TSLA', -0.086],
#   ['recall model X', -0.19],
#   ['Barclays signs on to Apple Pay', -0.113],
#   ['Could offer support revisit to jump on long bus?', 0.19],
#   ['ended the day down', 0.072],
#   ['Sounds bullish', 0.23],
#   ['$AAPL a new long IF 110.61 is broke', 0.174],
#   ['$TWTR Fck you Bird!', -0.085],
#   ['Santa Rally', 0.22],
#   ['Santa Rally', 0.22],
#   ['now a cloud software company. How the company transformed itself', 0.161],
#   ['ended the day down', -0.144],
#   ['zigzag and reversal scenario', -0.03],
#   ['the parties over', -0.223],
#   ['the parties over', -0.223],
#   ['go up 16% on no news', 0.145],
#   ['breaking out', 0.068],
#   ['continues to consolidate', 0.005],
#   ['2 retailers whose stocks I own', 0.227],
#   ['start strong finish weak', -0.086],
#   ['Wilful infringement does not go into calculations of patent damages $AAPL',
#    -0.207],
#   ["Report: Apple signs up for Google's cloud", -0.213],
#   ["If that's what you want then buy some", 0.245],
#   ['pushing to 12', 0.109],
#   ['issues already priced in', 0.165],
#   ['may rebound faster', 0.216],
#   ['ended the day down', -0.181],
#   ['careful can reverse fast', -0.152],
#   ['BlackBerry Messenger is second only to Facebook in user loyalty', 0.243],
#   ['no more buys', 0.146],
#   ['', 0.0],
#   ['Today I bought more', 0.087],
#   ['LED light bulb prices rise in Japan', 0.054],
#   ['put money in $hznp better option', -0.081],
#   ['Goldman Sachs reiterates conviction buy on', 0.087],
#   ['buy safety equipment maker for $2.5 billion', 0.23],
#   ['', 0.0],
#   ['We See More Reasons To Be Cautious', -0.093],
#   ['Friday was last chance under $2', 0.228],
#   ["Don't think buyout rumor strong enough too be driving this up just yet",
#    -0.02],
#   ['$YHOO +2.61%', 0.16],
#   ['$POZN +30', 0.146],
#   ['wants to ta', -0.23],
#   ['wants to ta', -0.23],
#   ['$UNT trying to break out of 5 day range', 0.244],
#   ['$UNT trying to break out of 5 day range', 0.244],
#   ['Today I bought more', 0.087],
#   ["today's bull flag", 0.2],
#   ['Long', 0.23],
#   ['Long', 0.23],
#   ['is in the process of streamlining its structure', 0.229],
#   ['is in the process of streamlining its structure', 0.229],
#   ['Yahoo, Facebook in Ad Partnership Talks', 0.249],
#   ['Moves on both sides possible', -0.023],
#   ['Moves on both sides possible', -0.023],
#   ['the parties over', -0.223],
#   ['the parties over', -0.223],
#   ['Brutal slide', -0.044],
#   ['covered the swing', 0.021],
#   ['It is cheap.', 0.183],
#   ['It is cheap.', 0.183],
#   ['It is cheap.', 0.183],
#   ['To Combine In $37 Billion Deal', 0.241],
#   ['Another quiet week', 0.0],
#   ['near-term target $77.38', 0.0],
#   ['airlines battle for Cuba routes $AAL $LUV $SAVE $JBLU', 0.092],
#   ['mrkt needs to washout', -0.055],
#   ['the most trending', 0.216],
#   ['Bullish yeah', 0.109],
#   ['Bullish yeah', 0.109],
#   ['$NLSN launching a marketing cloud', -0.245],
#   ['15 years after release, Windows XP is still the 3rd most popular OS', 0.2],
#   ["isn't going anywhere", 0.241],
#   ["isn't going anywhere", 0.241],
#   ['shorts breakin flag', 0.226],
#   ['the most trending', 0.216],
#   ['bail out', 0.058],
#   ['ready to break $QCOM watching at 55.7', 0.235],
#   ['Looks like one of the best values #Lithium stocks in the space', 0.197],
#   ['$BBRY smack down looks legitimate', -0.105],
#   ['$BBRY smack down looks legitimate', -0.105],
#   ['$BBRY smack down looks legitimate', -0.105],
#   ['Will we see $410 again', 0.152],
#   ['under $2 today?', -0.164],
#   ['Alibaba invests in Southeast Asian retailer Lazada', 0.0],
#   ['Alibaba invests in Southeast Asian retailer Lazada', 0.0],
#   ['the most trending', 0.216],
#   ['Higher In Afternoon Trade', 0.243],
#   ['Higher In Afternoon Trade', 0.243],
#   ['$AAPL a new long IF 110.61 is broke', 0.184],
#   ['Gevoâ€™s Alcohol to Jet Fuel Now Eligible to be Used for Commercial Flight',
#    0.031],
#   ['BMW entering into ride-share market with i3', 0.132],
#   ['hope kog shorters learned a lesson', 0.085],
#   ['hope kog shorters learned a lesson', 0.085],
#   ['interest level has skyrocketed here the last two week', 0.165],
#   ['Accumulating', -0.099],
#   ['taking a small chill pill today', -0.183],
#   ['Slips on Downgrade', -0.093],
#   ['Price experiencing early rejection', -0.228],
#   ['Will be adding on dips', 0.154],
#   ['Sold some $TSLA Puts this morning', -0.211],
#   ['famous lunch hour fade down routine', 0.002],
#   ['famous lunch hour fade down routine', 0.002],
#   ['Omg OMG so excited!!!!', 0.219],
#   ['I hope it gets resolved to the upside', 0.042],
#   ['shorts are trapped', 0.226],
#   ['No edge offered', 0.025],
#   ['Slips on Downgrade', -0.093],
#   ['', 0.172],
#   ['mrkt needs to washout', -0.055],
#   ['$TFM will have a way to go price wise to compete', -0.085],
#   ['trails $MSFT $ORCL $GOOG $CRM $ADBE', 0.179],
#   ["don't look for a dividend at the Feb Shareholders meeting", -0.2],
#   ['in the $3s', 0.0],
#   ['Sanofi often on the wrong end of business.', -0.247],
#   ['', 0.0],
#   ['Earnings will drive stock prices', 0.218],
#   ['thinking that last entry was good but needs a push', 0.207],
#   ['no position', -0.118],
#   ['Amazon has been selling surveillance cameras infected with malware',
#    -0.186],
#   ['brings upscale concept', 0.22],
#   ["I'm betting over 52%", -0.248],
#   ['careful can reverse fast', -0.152],
#   ['Buy Call!', 0.087],
#   ['Long', 0.23],
#   ['Long', 0.23],
#   ['So both call/put buyers are crushed', -0.126]],
#  1: [['watching for bounce tomorrow', 0.366],
#   ['record number of passengers served in 2015', 0.638],
#   ['Looking for a strong bounce', 0.46],
#   ['Looking for a strong bounce', 0.46],
#   ['Very intrigued with the technology and growth potential', 0.403],
#   ['Love this company long time.', 0.408],
#   ['runs into the 50sma on the acquisition news', 0.486],
#   ["t can't go down", 0.308],
#   ['mastered their supply chain', 0.461],
#   ['Most bullish stocks on Twitter during this dip', 0.408],
#   ['trade continuing very nicely from yesterday', 0.495],
#   ['trade continuing very nicely from yesterday', 0.495],
#   ['in from 3.61', 0.306],
#   ['Unusual call buying', 0.336],
#   ['reserves are in decline', 0.279],
#   ['all on a longer-term, technical swing long basis.', 0.591],
#   ["let's see a big bounce", 0.361],
#   ['above 2.25 and it could get going?', 0.26],
#   ['may feed off $TSLA momentum run lately.', 0.359],
#   ['possible double bottom set up', 0.29],
#   ['trading at all-time high', 0.887],
#   ['trading at all-time high', 0.887],
#   ['If positive outcome w/ lung study5/8 we may see a 13D Filing by Soros',
#    0.33],
#   ['Good idea buy half this and half BAC?', 0.329],
#   ['all on a longer-term, technical swing long basis.', 0.591],
#   ['stay long Apple', 0.337],
#   ['Unusual Call Activity', 0.332],
#   ["Can't imagine shorts wanting to go into the weekend without taking care of their position",
#    0.36],
#   ['$SIMO Basing nice', 0.408],
#   ['$SIMO Basing nice', 0.408],
#   ['Big Money Is Pouring Into Facebook From All Directions', 0.645],
#   ['go $FB go', 0.302],
#   ['Defying the Downturn', 0.407],
#   ['Found some good bull setups this week', 0.448],
#   ['sold my 81 calls', 0.328],
#   ["I'm watching(and buy targets)", 0.344],
#   ['beats the Estimize EPS Consensus by 6c and the Estimize Revenue Consensus by',
#    0.366],
#   ['Add to $FXP $SKF positions', 0.5],
#   ['long', 0.488],
#   ['$WMT, 13%', 0.382],
#   ['added', 0.274],
#   ['added', 0.274],
#   ['$FCX +3.53%', 0.339],
#   ['Fed cuts rates forecast', 0.449],
#   ['Fed cuts rates forecast', 0.449],
#   ['#oversold', 0.406],
#   ['a great step for #China to let $FB in', 0.417],
#   ['Pie In The Sky', 0.365],
#   ['Moved Upper Bollinger Band', 0.498],
#   ['Highest call to put ratio', 0.348],
#   ['offers will take place until next week', 0.409],
#   ['breaking out when the market pulls back', 0.413],
#   ["Buy the dip'", 0.38],
#   ['Headed to all time highs', 0.407],
#   ['buy', 0.458],
#   ['Buying on Weakness', 0.511],
#   ['Shareholders welcome Marriott-Starwood deal', 0.322],
#   ['peachy prospects', 0.339],
#   ['Nice day rally!', 0.529],
#   ['Nice day rally!', 0.529],
#   ['Quality Stocks With High Cash Returns', 0.274],
#   ['Closed Buy', 0.466],
#   ['With $IBB back over support', 0.285],
#   ['long into earnings', 0.484],
#   ['long into earnings', 0.484],
#   ['considering Yahoo bid', 0.288],
#   ['considering Yahoo bid', 0.288],
#   ['I will buy aggressively if pulls back', 0.386],
#   ['Nice day rally!', 0.529],
#   ['Buying on Weakness', 0.511],
#   ['Could that have been a strategy to exit shorts before the big pop?',
#    0.316],
#   ['Piper upgrades Symantec on improving renewal rates and enterprise growth',
#    0.525],
#   ['Look for strong solar rebound today!', 0.304],
#   ['Watchlist Top Stocks', 0.342],
#   ['Long', 0.428],
#   ['patience pays off', 0.272],
#   ['sales numbers still holding up so well', 0.315],
#   ['sales numbers still holding up so well', 0.315],
#   ['just about to break out to new highs', 0.469],
#   ['just about to break out to new highs', 0.469],
#   ['this will pop after the holiday', 0.555],
#   ['News breaks first and fastest on Twitter $TWTR', 0.364],
#   ['Continues to consolidate above previous break out area.', 0.375],
#   ['Good to load up Be confident', 0.281],
#   ['Long', 0.394],
#   ['Long', 0.394],
#   ['but decent supt here-expect some upside', 0.302],
#   ['Sector has been taking a beating recently, could be positive here', 0.361],
#   ['Sector has been taking a beating recently, could be positive here', 0.361],
#   ['At 11x earnings, $AAPL is a steal', 0.561],
#   ['calls for nice gains', 0.396],
#   ['calls for nice gains', 0.396],
#   ['calls for nice gains', 0.396],
#   ['someone bought lots of calls MON', 0.444],
#   ['ready to exit bankruptcy', 0.298],
#   ['starting to creep up', 0.28],
#   ['looks like BO coming', 0.36],
#   ['Moved Upper Bollinger Band', 0.498],
#   ['Supermarket Stocks Rally as Tesco Plans to Axe Non-core UK Assets', 0.346],
#   ['China winners', 0.452],
#   ['looks like an ascending channel', 0.363],
#   ['Oil To Break Out', 0.666],
#   ['Oil To Break Out', 0.666],
#   ['Top #NetPayoutYields', 0.426],
#   ['Long $AMZN Oct $240 Calls', 0.628],
#   ['patience pays off', 0.272],
#   ['making new highs for the year', 0.53],
#   ['held up well after the big gains!', 0.695],
#   ['held up well after the big gains!', 0.695],
#   ['want to go this morning', 0.28],
#   ['want to go this morning', 0.28],
#   ['Oil To Break Out', 0.666],
#   ['Oil To Break Out', 0.666],
#   ['added $SSO 64.33', 0.626],
# ...
#   ['gap up tomorrow', 0.439],
#   ['demand ahead', 0.532],
#   ['demand ahead', 0.532],
#   ['Our updated #core4 portfolio', 0.452],
#   ['new HOD with conviction keeping $570 on watch for Resistance', 0.529],
#   ['long the market', 0.525],
#   ['Best outperformers ranked', 0.492],
#   ['Watchlist Top Stocks', 0.342],
#   ['I would consider this opportunity to add my position', 0.401],
#   ['I would consider this opportunity to add my position', 0.401],
#   ['took some $ENDP long this am', 0.613],
#   ['Yes buy everything up', 0.829],
#   ['A Premier Retail Dividend Play', 0.354],
#   ['beat', 0.284],
#   ['beat', 0.284],
#   ['long', 0.537],
#   ['Bullish MA Crossovers', 0.457],
#   ['Unusual Call Activity', 0.421],
#   ['Nice day rally!', 0.529],
#   ['Added long at friday close', 0.513],
#   ['Long over 3.95/great find - hope that wold be another $ANLY or $PZZI, still holding second 1/2',
#    0.509],
#   ['Pushing Channel Development', 0.458],
#   ['bot $EZPW', 0.437],
#   ['Like this >', 0.374],
#   ['Like this >', 0.374],
#   ['580+ should be coming very quick, if the FED supports the markets 610',
#    0.296],
#   ['some of the stocks that came up on screens for longs', 0.431],
#   ['Sector Stocks Leading Today', 0.454],
#   ['Airplane And Hospitality Industries Set Their Sights On #Cuba', 0.405],
#   ['Over 16 with conviction', 0.585],
#   ['Over 16 with conviction', 0.585],
#   ['Over 16 with conviction', 0.585],
#   ['Some competitors worry that BlackBerry is the inevitable successor to Northern Telecom',
#    0.27],
#   ['Some competitors worry that BlackBerry is the inevitable successor to Northern Telecom',
#    0.27],
#   ['Moved Upper Bollinger Band', 0.498],
#   ['Unusual Call Activity', 0.332],
#   ['TOP 5 STOCK PICKS', 0.414],
#   ['ascending base breakout starting to gain traction', 0.733],
#   ['ascending base breakout starting to gain traction', 0.733],
#   ['Top holdings', 0.311],
#   ['Expands Share Repurchase Program', 0.285],
#   ['Play safe, be long', 0.335],
#   ['Play safe, be long', 0.335],
#   ['Bullish yeah', 0.393],
#   ['Bullish yeah', 0.393],
#   ['New RSI signal created on $COST - Buy', 0.497],
#   ['holding up well today', 0.318],
#   ['Unusual Call Activity', 0.421],
#   ['all higher', 0.293],
#   ['stocks at support w/ high trade quality', 0.503],
#   ['gapping up to all time highs', 0.782],
#   ['Fed cuts rates forecast', 0.449],
#   ['Fed cuts rates forecast', 0.449],
#   ['Finding Support', 0.259],
#   ['confirmation is a hold ', 0.259],
#   ['confirmation is a hold ', 0.259],
#   ["Sounds like we'll see some green tomorrow", 0.395],
#   ['closed Friday with the RS line in new highs', 0.371],
#   ['Beautiful trend/base', 0.645],
#   ['Beautiful trend/base', 0.645],
#   ['Beautiful trend/base', 0.645],
#   ['Beautiful trend/base', 0.645],
#   ['Airplane And Hospitality Industries Set Their Sights On #Cuba', 0.405],
#   ['over 225 million new Internet users are being added globally every year',
#    0.337],
#   ['Unusual call buying', 0.336],
#   ['probably long', 0.29],
#   ['Unusual Call Activity', 0.421],
#   ['Loooooongggggg base', 0.557],
#   ['$PYPL w/ a solid start in #ecommerce checkout', 0.375],
#   ['want to go this morning', 0.28],
#   ['want to go this morning', 0.28],
#   ['Nobody is recommending the sale of this stock', 0.623],
#   ['Nobody is recommending the sale of this stock', 0.623],
#   ['all on a longer-term, technical swing long basis.', 0.591],
#   ['This stock is such a winner', 0.451],
#   ['Pivotal upgrades Alphabet ahead of Q1 results', 0.53],
#   ['was still up on the screen', 0.377],
#   ['some upside today', 0.254],
#   ['some upside today', 0.254],
#   ['Will be looking to add shares if we get a new high breakout', 0.421],
#   ['#whisperbeat', 0.619],
#   ['BMW entering into ride-share market with i3', 0.399],
#   ['Rally Friday!', 0.66],
#   ['Rally Friday!', 0.66],
#   ['Rally Friday!', 0.66],
#   ['staying strong', 0.532],
#   ['they have real assets', 0.432],
#   ['Finding Support', 0.259],
#   ["Buy these 3 stocks while there's blood in the streets", 0.415],
#   ['Google, Inc. completes acquisition of ICOA', 0.267],
#   ['Stocks Higher In Afternoon Trade', 0.314],
#   ['Looking for continuation with volume increase', 0.308],
#   ['Top #NetPayoutYields', 0.426],
#   ['not dipping - testing the 200 day ma', 0.281],
#   ['should reward better on good earnings', 0.326],
#   ['In play tmrw', 0.805],
#   ['Sector Stocks Leading Today', 0.454],
#   ['bidding war picks up for the company', 0.391],
#   ['China winners', 0.452],
#   ['shares up ~7% after hours', 0.552],
#   ['shares up ~7% after hours', 0.552],
#   ['seriously nothing says strong growth like', 0.312],
#   ['seriously nothing says strong growth like', 0.312],
#   ['Call credit spread', 0.311],
#   ['bought 3500 shares today!', 0.738],
#   ['LNKD is great but doesnt the potential side with Fb', 0.283],
#   ['Bought more - Bought $FB at', 0.506],
#   ['indicators turning up', 0.351],
#   ['indicators turning up', 0.351],
#   ['great company', 0.408],
#   ['long $AAPL', 0.648],
#   ['on the move up again', 0.483],
#   ['ooks like nice risk/reward for starting to initiate a position', 0.309],
#   ['ooks like nice risk/reward for starting to initiate a position', 0.309],
#   ['Favorite Stocks', 0.401],
#   ['buy $WFM', 0.474],
#   ['run run $AMZN up 4.4% now', 0.482],
#   ['Covered Call', 0.329],
#   ['earnings were good', 0.336],
#   ['tremendous opportunity awaits', 0.384],
#   ['Dividend Hike Green Light', 0.316],
#   ['Good to load up Be confident', 0.281],
#   ['long', 0.388],
#   ['Aggressive Buy', 0.306],
#   ['Highest call to put ratio', 0.348],
#   ['Stream too bullish', 0.492],
#   ['Stream too bullish', 0.492],
#   ['breakouts', 0.627],
#   ['Looking for a oversold bounce', 0.436],
#   ['Analysts impressed with progress', 0.474],
#   ['stocks insiders are bullish on', 0.433],
#   ['Biggest gainers today large caps', 0.432],
#   ['holding up well today', 0.318],
#   ['stocks insiders are bullish on', 0.433],
#   ['Highest call to put ratio', 0.348],
#   ["Don't short this stock", 0.402],
#   ['Impressive numbers', 0.443],
#   ['I am excited about all these plays', 0.322],
#   ["I've been picking up railroad stocks for the retirement acct", 0.441],
#   ['LONGS', 0.511],
#   ['$TOL', 0.353],
#   ['$TOL', 0.353],
#   ['short didnt work out', 0.378],
#   ['Best outperformers ranked', 0.492],
#   ['breakout very likely', 0.518],
#   ['my buddy bet the bank', 0.432],
#   ['high risk but could be a sweet ST runner once the jigginess exits', 0.322],
#   ['trying to lead higher here', 0.256],
#   ['Multi-year stock breakouts', 0.612],
#   ['', 0.251],
#   ['Announces Sale of Partial Stake', 0.262],
#   ['Biggest gainers today large caps', 0.376],
#   ['2nd raise this year.', 0.705],
#   ['2nd raise this year.', 0.705],
#   ['$KNDI China electric car maker. China car sales +7.8%.', 0.403],
#   ['Looking for a strong bounce', 0.46],
#   ['Looking for a strong bounce', 0.46],
#   ['Looking for a strong bounce', 0.521],
#   ['Looking for a strong bounce', 0.521],
#   ['Cisco-Synata deal is a game-changer $CSCO', 0.304],
#   ['ready to pop!', 0.293],
#   ["Amazon declares 'best ever' Black Friday and Cyber Monday for Kindle family",
#    0.434],
#   ['working on Cuba deals', 0.419],
#   ['giddy up!', 0.308],
#   ['Holy green day batman', 0.298],
#   ['Holy green day batman', 0.298],
#   ['Rally Friday!', 0.66],
#   ['Rally Friday!', 0.66],
#   ['Rally Friday!', 0.66],
#   ['Unusual Call Activity', 0.421],
#   ['EPS growth is around 12% so far', 0.316],
#   ['Moved Upper Bollinger Band', 0.498],
#   ['Look at that $AMZN > 600', 0.326],
#   ['up almost 11% now', 0.398],
#   ['mkt should stableize a little', 0.315],
#   ['closed Friday with the RS line in new highs', 0.371],
#   ['big $QQQ up day', 0.432],
#   ['the selling days appear exhausted', 0.376],
#   ['shorts start quietly covering', 0.37],
#   ['AUG 645 calls +550%', 0.553],
#   ['huge buy in all these names', 0.608],
#   ['In Play Longs', 0.273],
#   ['magically bought at under a dollar', 0.288],
#   ['Covered my small $MWW short', 0.348],
#   ['Found some good bull setups this week', 0.448],
#   ['raises Q2, FY12 guidance', 0.501],
#   ["I'll take the other side of that trade", 0.422],
#   ['massive recent recovery toward new highs should give the real shareholders encouragement on questcor',
#    0.448],
#   ['Sector Stocks Leading Today', 0.454],
#   ['First quarter is amazing', 0.322],
#   ['Biggest gainers today large caps', 0.462],
#   ['stocks at support w/ high trade quality', 0.503],
#   ['Guess the late traders will be stocking up on $TSLA', 0.416],
#   ['Rally Friday!', 0.66],
#   ['Rally Friday!', 0.66],
#   ['Rally Friday!', 0.66],
#   ['may be ripe for a #takeover targe', 0.343],
#   ['on watch for everyone on Tuesday night for a serious breakout', 0.448],
#   ['betting that $GOOG buys Twitter', 0.261],
#   ['Highest call to put ratio', 0.348],
#   ['Breakout in Regional Banking', 0.563],
#   ['is somewhat tempting on the long side here', 0.421],
#   ['New bullish conversation activity', 0.461],
#   ['Both look good to me', 0.392],
#   ['Good to load up Be confident', 0.281],
#   ['If positive outcome w/ lung study5/8 we may see a 13D Filing by Soros',
#    0.33],
#   ["Google, IBM, ARM And AMD Begin The Assault On Intel's Server Franchise",
#    0.372],
#   ['Support here @ 50sma', 0.328],
#   ['Support here @ 50sma', 0.328],
#   ["Report: Apple signs up for Google's cloud", 0.443],
#   ['get up out of that Bermuda Triangle', 0.3],
#   ['get up out of that Bermuda Triangle', 0.3],
#   ['Institutions seem to like this class of stocks', 0.422],
#   ['Going to be EPIC', 0.367],
#   ['Good thing', 0.277],
#   ['Good thing', 0.277],
#   ['Still the top dog', 0.473],
#   ['stock has 41% upside from here', 0.447],
#   ['Nice day rally!', 0.529],
#   ['Nice start', 0.269],
#   ['Closed Buy', 0.466],
#   ['$TROV reliably finding cancer mutations', 0.267],
#   ['$TROV reliably finding cancer mutations', 0.267],
#   ['Nice little cup-and-handle shaping up', 0.326],
#   ['Nice little cup-and-handle shaping up', 0.326],
#   ['LOOKS like we are bouncing', 0.391],
#   ['LOOKS like we are bouncing', 0.391],
#   ['Gaining Momentum!', 0.527],
#   ['Gaining Momentum!', 0.527],
#   ['Gaining Momentum!', 0.527],
#   ['Surges On Deal', 0.419],
#   ['long this morning', 0.476],
#   ['trade continuing very nicely from yesterday', 0.495],
#   ['trade continuing very nicely from yesterday', 0.495],
#   ['slow-motion disruption of the global auto industry', 0.601],
#   ['Potential intermediate top in an Uptrend', 0.32],
#   ['stocks at support w/ high trade quality', 0.503],
#   ['closng higher from here', 0.48],
#   ['Take it while you can', 0.515],
#   ['lets see 14+ today', 0.302],
#   ['bought CALL OMNIVISION TECH', 0.722],
#   ['bought CALL OMNIVISION TECH', 0.722],
#   ['Pie In The Sky', 0.365],
#   ['EPS growth is around 12% so far', 0.316],
#   ['producing a Bullish MACD Xover', 0.691],
#   ['bidders line up', 0.252],
#   ['expecting $SPY to close above', 0.385],
#   ['LONGS', 0.511],
#   ['notice how the doomsaying bears disappear during the climbs', 0.467],
#   ['watch is showing serious demand', 0.491],
#   ['Prob a buy if it does', 0.428],
#   ['sales exceed target', 0.526],
#   ['sales exceed target', 0.526],
#   ['stock will hit $170 easily', 0.327],
#   ['Downbeaten stocks may be ripe for buys', 0.316],
#   ['shorts are getting nervous', 0.366],
#   ['Monday Bulls Are Out!', 0.457],
#   ["today's top gainers", 0.447],
#   ['Aggressive Buy', 0.306],
#   ['mentioned as potential suitee, suitor', 0.258],
#   ['$TPLM Triangle #Petroleum 9.80+3% 2M Expanding Caliber', 0.376],
#   ['Downbeaten stocks may be ripe for buys', 0.316],
#   ['Daily Mail enters competition to acquire Yah', 0.342],
#   ['Stocks Higher In Afternoon Trade', 0.357],
#   ['Watchlist Top Stocks', 0.342],
#   ['Sudden optimism about iPhone sales', 0.279],
#   ['Sudden optimism about iPhone sales', 0.279],
#   ['Sudden optimism about iPhone sales', 0.279],
#   ["Google, IBM, ARM And AMD Begin The Assault On Intel's Server Franchise",
#    0.368],
#   ['Bullish MA Crossovers', 0.457],
#   ['Watchlist Top Stocks', 0.342],
#   ['looks constructive', 0.28],
#   ['long play', 0.48],
#   ['long play', 0.48],
#   ['good for economy', 0.273],
#   ['Inside week buy triggers', 0.485],
#   ['revenue grew double-digit', 0.454],
#   ['Long $TSLA', 0.607],
#   ['In Play Longs', 0.273],
#   ['MACD and ADX are crossing over the signal lines!', 0.569],
#   ['MACD and ADX are crossing over the signal lines!', 0.569],
#   ["Buy the dip'", 0.38],
#   ['About to break out on the 5-min', 0.313],
#   ['Long over 3.95/great find - hope that wold be another $ANLY or $PZZI, still holding second 1/2',
#    0.509],
#   ['Fed cuts rates forecast', 0.449],
#   ['Fed cuts rates forecast', 0.449],
#   ['up almost', 0.378],
#   ['up almost', 0.378],
#   ['$LEI Higher', 0.388],
#   ['Breakout watch', 0.352],
#   ['adding to position here', 0.685],
#   ['Looks good on the weekly chart', 0.379],
#   ['holding up relatively well compared to the broad market', 0.394],
#   ['Bullish MA Crossovers', 0.457],
#   ['Top Stocks in 2015 are Ready to Lead Again in 2016', 0.414],
#   ['making new HOD', 0.442],
#   ['Most bullish stocks on Twitter during this dip', 0.408],
#   ['strong move today for the Junior Gold Miners', 0.75],
#   ['strong move today for the Junior Gold Miners', 0.75],
#   ['Why The Coal & Shipping Sectors Could Rise Again', 0.418],
#   ['looking good', 0.362],
#   ['looking good', 0.362],
#   ['Equity indexes working on a positive engulfing for March', 0.308],
#   ['and it will continue', 0.413],
#   ['and it will continue', 0.413],
#   ['$FB is taking the shine off $AAPL and $GOOG', 0.435],
#   ['holding up nicely', 0.441],
#   ['Bought $FB $111 calls', 0.579],
#   ['Airplane And Hospitality Industries Set Their Sights On #Cuba', 0.405],
#   ['Come on and run with the bulls today', 0.484],
#   ['5 Best Analyst Rated Stocks', 0.509],
#   ['nothing investors can do to damage Apple', 0.322],
#   ["Don't underestimate Mark", 0.37],
#   ["Don't underestimate Mark", 0.37],
#   ['Unusual Call Activity', 0.421],
#   ['buy more on the weakness?', 0.346],
#   ['Good time to buy', 0.533],
#   ['Call sweepers stepping up this morning', 0.343],
#   ['so i can add more', 0.307],
#   ['hearing rumours of a major joint venture announcement', 0.427],
#   ['weakness could be opportunity', 0.345],
#   ['weakness could be opportunity', 0.345],
#   ['citing positive spending trends', 0.436],
#   ['Sector Stocks Leading Today', 0.454],
#   ['In Play Longs', 0.273],
#   ['it shoots to the MOON as my favorite pumper', 0.514],
#   ['Best performers', 0.307],
#   ['Equities recently tagged #undervalued', 0.353],
#   ['do i have enough shares ???', 0.429],
#   ['do i have enough shares ???', 0.429],
#   ['added to $DNKN (longs)', 0.528],
#   ['TOP 5 STOCK PICKS', 0.414],
#   ['People still coming in', 0.257],
#   ['People still coming in', 0.257],
#   ['Bigger win for', 0.273],
#   ['over 225 million new Internet users are being added globally every year',
#    0.337],
#   ["Grab it while it's cheap", 0.488],
#   ['adding $expe and $pcln to the mix soon', 0.408],
#   ['adding $expe and $pcln to the mix soon', 0.408],
#   ['making all kinds of gains ????', 0.42],
#   ['looking to add a gold miner and possibly lower pe tech name into close',
#    0.425],
#   ['Marriott wins new Starwood deal by raising cash portion of bid', 0.332],
#   ['Watchlist Top Stocks', 0.342],
#   ['soars pre-market', 0.398],
#   ['allow for the growing middle class', 0.289],
#   ['allow for the growing middle class', 0.289],
#   ['Oil To Break Out', 0.666],
#   ['Oil To Break Out', 0.666],
#   ['growing customers globally', 0.576],
#   ['growing customers globally', 0.576],
#   ['an upward movement is expected', 0.387],
#   ['will get in on the next run up', 0.275],
#   ['Fed cuts rates forecast', 0.449],
#   ['Fed cuts rates forecast', 0.449],
#   ["Buy the dip'", 0.38],
#   ['next year could be a very good year for them', 0.528],
#   ['next year could be a very good year for them', 0.528],
#   ['Launch Updated Model S With Steeper Price Tag', 0.261],
#   ['$AMZN is becoming more and more the go-to site for almost all categories in ecommerce.',
#    0.269],
#   ['$AAPL could pick em up too.', 0.324],
#   ['record number of passengers served in 2015', 0.638],
#   ['ure has lots of attractive suitors', 0.325],
#   ["delivering the goods again let's see if that can spill over in other chinese internet names",
#    0.502],
#   ...]}

# %%
print('Negative headlines => ', str(len(pos_neg_neu_train[-1])),'\nNeutral headlines => ', str(len(pos_neg_neu_train[0])),'\nPositive headlines => ', str(len(pos_neg_neu_train[1])))
# Out:
# Negative headlines =>  562
# Neutral headlines =>  426
# Positive headlines =>  1090

# %%
pos_neg_neu_val = {-1:[], 0:[], 1:[]}

for i in mb_val.values:
    if(i[3]>-1 and i[3]<=-0.25):
#         pos_neg_neu_val[-1].append([i[1], i[3]])
        if(len(i[1])==1):
            pos_neg_neu_val[-1].append([i[1][0], i[3]])
        elif(len(i[1])>1):
            for k in i[1]:
                pos_neg_neu_val[-1].append([i[1][0], i[3]])
    if(i[3]>-0.25 and i[3]<=0.25):
#         pos_neg_neu_val[0].append([i[1], i[3]])
        if(len(i[1])==1):
            pos_neg_neu_val[0].append([i[1][0], i[3]])
        elif(len(i[1])>1):
            for k in i[1]:
                pos_neg_neu_val[0].append([i[1][0], i[3]])
    if(i[3]>0.25 and i[3]<=1):
#         pos_neg_neu_val[1].append([i[1], i[3]])
        if(len(i[1])==1):
            pos_neg_neu_val[1].append([i[1][0], i[3]])
        elif(len(i[1])>1):
            for k in i[1]:
                pos_neg_neu_val[1].append([i[1][0], i[3]])

# %%
pos_neg_neu_val
# Out:
# {-1: [['Putting on a little $F short', -0.454],
#   ['short some', -0.464],
#   ['its time to sell banks', -0.763],
#   ['is a short below 740', -0.48],
#   ['is a short below 740', -0.48]],
#  0: [],
#  1: [['buying opportunity', 0.445],
#   ['Scaling Up on Long Position', 0.661],
#   ['Entering long', 0.627],
#   ['picked some up', 0.653],
#   ['time to accumulate for a long position', 0.668],
#   ['time to accumulate for a long position', 0.668],
#   ['Buying $SBUX on dip', 0.483]]}

# %%
print('Negative headlines => ', str(len(pos_neg_neu_val[-1])),'\nNeutral headlines => ', str(len(pos_neg_neu_val[0])),'\nPositive headlines => ', str(len(pos_neg_neu_val[1])))
# Out:
# Negative headlines =>  5
# Neutral headlines =>  0
# Positive headlines =>  7

# %%
X_vals_tr = []
for i in pos_neg_neu_train:
    for j in pos_neg_neu_train[i]:
        X_vals_tr.append([j[0]])
        if(i == -1):
            X_vals_tr[-1].extend(['Negative'])
        elif(i == 0):
            X_vals_tr[-1].extend(['Neutral'])
        else:
            X_vals_tr[-1].extend(['Positive'])
X_vals_tr = np.array(X_vals_tr)

# %%
X_vals_tr
# Out:
# array([['out $NFLX -.35', 'Negative'],
#        ['overbought', 'Negative'],
#        ['absolute garbage still up', 'Negative'],
#        ...,
#        ['Buy stop above 80', 'Positive'],
#        ['Airplane And Hospitality Industries Set Their Sights On #Cuba',
#         'Positive'],
#        ['nice bounce', 'Positive']], dtype='<U129')

# %%
microBlog_train = pd.DataFrame({'Title':X_vals_tr[:,0],'Sentiment':X_vals_tr[:,1]})

# %%
X_vals_vl = []
for i in pos_neg_neu_val:
    for j in pos_neg_neu_val[i]:
        X_vals_vl.append([j[0]])
        if(i == -1):
            X_vals_vl[-1].extend(['Negative'])
        elif(i == 0):
            X_vals_vl[-1].extend(['Neutral'])
        else:
            X_vals_vl[-1].extend(['Positive'])
X_vals_vl = np.array(X_vals_vl)

# %%
X_vals_vl[0]
# Out:
# array(['Putting on a little $F short', 'Negative'], dtype='<U38')

# %%
microBlog_val = pd.DataFrame({'Title':X_vals_vl[:,0],'Sentiment':X_vals_vl[:,1]})

# %%
microBlog_val.head()
# Out:
#                                                Title Sentiment
# 0  Tesco says UK store closures put 2000 jobs at ...  Negative
# 1  Reed Elsevier share price slides on underwhelm...  Negative
# 2  Kingfisher bid for Mr Bricolage runs into trouble  Negative
# 3  Kingfisher bid for Mr Bricolage runs into trouble  Negative
# 4    Diageo stays neutral on India boardroom turmoil   Neutral

# %%
microBlog_train.head()
# Out:
#                        Title Sentiment
# 0             out $NFLX -.35  Negative
# 1                 overbought  Negative
# 2  absolute garbage still up  Negative
# 3  absolute garbage still up  Negative
# 4  absolute garbage still up  Negative

# %%
microBlog = pd.concat([microBlog_train,microBlog_val])

# %%
microBlog.head()
# Out:
#                        Title Sentiment
# 0             out $NFLX -.35  Negative
# 1                 overbought  Negative
# 2  absolute garbage still up  Negative
# 3  absolute garbage still up  Negative
# 4  absolute garbage still up  Negative

# %% [markdown]
# # Word2Vec

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from gensim.models import Word2Vec

# %%
from nltk.tokenize import word_tokenize

# %%
import gensim

# %%
pretext_h=microBlog["Title"].apply(gensim.utils.simple_preprocess)

# %%
pretex=[" ".join(i) for i in pretext_h]

# %%
pretext_h = [i for i in pretext_h.values]

# %%
wvmodel = Word2Vec(pretext_h, vector_size=300, window=5, min_count=1, workers=4)

# %%
train_features = []
for i in tqdm(pretext_h):
    s = np.zeros(wvmodel.vector_size,dtype='float32')
    for j in i:
        s+=wvmodel.wv.get_vector(wvmodel.wv.key_to_index[j])
    train_features.append(s)
train_features = np.array(train_features)
# Out:
# 100%|██████████| 2090/2090 [00:00<00:00, 41076.12it/s]

# %%
train_labels = microBlog['Sentiment'].values

# %%
train_features, test_features, train_labels, test_labels = train_test_split(train_features, train_labels, test_size=0.2, random_state=42)

# %%
train_features.shape
# Out:
# (1672, 300)

# %%
test_features.shape
# Out:
# (418, 300)

# %% [markdown]
# # Model Training

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn import svm

# %%
clf = LogisticRegression(random_state=0, solver='lbfgs', penalty='l2')

# %%
clf.fit(train_features, train_labels)
# Out:
# LogisticRegression(random_state=0)

# %%
# print('Validation Accuracy= '+str(clf.score(val_features, val_labels))+'%')
# for train data:        
print('From train set Accuracy= '+str(clf.score(test_features, test_labels))+'%')
# Out:
# From train set Accuracy= 0.5215311004784688%

# %%
clf = svm.SVC(degree=10)
clf.fit(train_features, train_labels)
# Out:
# SVC(degree=10)

# %%
scores = cross_val_score(clf, test_features, test_labels, cv=10)

# %%
# print('Validation Accuracy= '+str(clf.score(val_features, val_labels))+'%')
# for train data:        
print('From train set Accuracy= '+str(np.mean(scores))+'%')
# Out:
# From train set Accuracy= 0.5216027874564461%

# %%
clf = make_pipeline(StandardScaler(),svm.SVC(random_state=0, degree=10, tol=1e-5, C=2))
clf.fit(train_features, train_labels)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('svc', SVC(C=2, degree=10, random_state=0, tol=1e-05))])

# %%
scores = cross_val_score(clf, test_features, test_labels, cv=10)

# %%
# print('Validation Accuracy= '+str(clf.score(val_features, val_labels))+'%')
# for train data:        
print('From train set Accuracy= '+str(np.mean(scores))+'%')
# Out:
# From train set Accuracy= 0.643321718931475%

# %%
clf = RandomForestClassifier(max_depth=100, random_state=0, criterion='entropy')
clf.fit(train_features, train_labels)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=100, random_state=0)

# %%
scores = cross_val_score(clf, test_features, test_labels, cv=10)

# %%
# print('Validation Accuracy= '+str(clf.score(val_features, val_labels))+'%')
# for train data:        
print('From train set Accuracy= '+str(np.mean(scores))+'%')
# Out:
# From train set Accuracy= 0.6458768873403018%

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
clf = KNeighborsClassifier(n_neighbors=20)
clf.fit(train_features, train_labels)
# Out:
# KNeighborsClassifier(n_neighbors=20)

# %%
scores = cross_val_score(clf, test_features, test_labels, cv=10)

# %%
# print('Validation Accuracy= '+str(clf.score(val_features, val_labels))+'%')
# for train data:        
print('From train set Accuracy= '+str(np.mean(scores))+'%')
# Out:
# From train set Accuracy= 0.5265969802555167%

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
clf = GradientBoostingClassifier(n_estimators=75, learning_rate=1.0, max_depth=1, random_state=0)
clf.fit(train_features, train_labels)
# Out:
# GradientBoostingClassifier(learning_rate=1.0, max_depth=1, n_estimators=75,
#                            random_state=0)

# %%
scores = cross_val_score(clf, test_features, test_labels, cv=10)

# %%
# print('Validation Accuracy= '+str(clf.score(val_features, val_labels))+'%')
# for train data:        
print('From train set Accuracy= '+str(np.mean(scores))+'%')
# Out:
# From train set Accuracy= 0.6364111498257838%
